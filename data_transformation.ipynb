# %%
def test_function():
    return None

# %%
print("hello")
# Out:
# hello

# %%
x=2
y=1
z= x + y
print(z)
# Out:
# 3

# %%
def ingest_csv(df):
  #some logic here

def ingest_json(df2):
  #some logic here
# Out:
#   Cell In[3], line 4
#     def ingest_json(df2):
#     ^
# IndentationError: expected an indented block after function definition on line 1
